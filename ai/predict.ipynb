# %%
from ultralytics import YOLO

# %%
model = YOLO("./runs/detect/train2/weights/best.pt")

# %%
results = model("./1.jpg")
# Out:
# image 1/1 /home/j-j10b102/ai/1.jpg: 320x256 1 200704590-펠루비정(펠루비프로펜), 1 199907419-정장생캡슐(바실루스리케니포르미스균) , 34.1ms
# Speed: 4.8ms preprocess, 34.1ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 256)

# %%
for result in results:
    result.show()
# Out:
# <PIL.Image.Image image mode=RGB size=1080x1440>
