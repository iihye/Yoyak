# %%
import zipfile
from glob import glob
import os

# %%
path = "/home/j-j10b102/166.약품식별_인공지능_개발을_위한_경구약제_이미지_데이터/01.데이터/1.Training/라벨링데이터/단일경구약제_5000종/*.zip"

# print(glob(path)[0])
# zip_path = glob(path)[0]


# filename, _ = os.path.splitext(zip_path)
# # filename

# with zipfile.ZipFile(glob(path)[0], 'r') as zip_ref:
#     if(os.path.exists(filename)):
#         pass
#     else:
#         os.mkdir(filename)
#         zip_ref.extractall(filename)
#     print(glob(filename+"/*"))
#     for json_folder in glob(filename+"/*"):
#         print(json_folder)
#     print(len(glob(filename+"/**/*")))
#     for txt in glob(filename+"/**/*"):

# %%
for zip_path in glob(path):
    folder, _ = os.path.splitext(zip_path)
    print(folder)
    
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        if(os.path.exists(folder)):
            pass
        else:
            os.mkdir(folder)
            zip_ref.extractall(folder)
# Out:
# /home/j-j10b102/166.약품식별_인공지능_개발을_위한_경구약제_이미지_데이터/01.데이터/1.Training/라벨링데이터/단일경구약제_5000종/TL_74_단일
# /home/j-j10b102/166.약품식별_인공지능_개발을_위한_경구약제_이미지_데이터/01.데이터/1.Training/라벨링데이터/단일경구약제_5000종/TL_19_단일
# /home/j-j10b102/166.약품식별_인공지능_개발을_위한_경구약제_이미지_데이터/01.데이터/1.Training/라벨링데이터/단일경구약제_5000종/TL_32_단일
# /home/j-j10b102/166.약품식별_인공지능_개발을_위한_경구약제_이미지_데이터/01.데이터/1.Training/라벨링데이터/단일경구약제_5000종/TL_29_단일
# /home/j-j10b102/166.약품식별_인공지능_개발을_위한_경구약제_이미지_데이터/01.데이터/1.Training/라벨링데이터/단일경구약제_5000종/TL_31_단일
# /home/j-j10b102/166.약품식별_인공지능_개발을_위한_경구약제_이미지_데이터/01.데이터/1.Training/라벨링데이터/단일경구약제_5000종/TL_77_단일
# /home/j-j10b102/166.약품식별_인공지능_개발을_위한_경구약제_이미지_데이터/01.데이터/1.Training/라벨링데이터/단일경구약제_5000종/TL_41_단일
# /home/j-j10b102/166.약품식별_인공지능_개발을_위한_경구약제_이미지_데이터/01.데이터/1.Training/라벨링데이터/단일경구약제_5000종/TL_1_단일
# /home/j-j10b102/166.약품식별_인공지능_개발을_위한_경구약제_이미지_데이터/01.데이터/1.Training/라벨링데이터/단일경구약제_5000종/TL_3_단일
# /home/j-j10b102/166.약품식별_인공지능_개발을_위한_경구약제_이미지_데이터/01.데이터/1.Training/라벨링데이터/단일경구약제_5000종/TL_30_단일
# ...

# %%
path = "/home/j-j10b102/166.약품식별_인공지능_개발을_위한_경구약제_이미지_데이터/01.데이터/1.Training/라벨링데이터/단일경구약제_5000종/*.zip"

folder_path = "/home/j-j10b102/166.약품식별_인공지능_개발을_위한_경구약제_이미지_데이터/01.데이터/1.Training/라벨링데이터/단일경구약제_5000종/*"

items = glob(folder_path)
folders = []
zips = []
for item in items:
    item_path = os.path.join(folder_path, item)
    
    if not os.path.isdir(item_path):
        print(item_path)
        os.remove(item_path)
#     if os.path.isdir(item_path):
#         folders.append(item)
#     else:
#         zips.append(item)
# Out:
# /home/j-j10b102/166.약품식별_인공지능_개발을_위한_경구약제_이미지_데이터/01.데이터/1.Training/라벨링데이터/단일경구약제_5000종/TL_74_단일.zip
# /home/j-j10b102/166.약품식별_인공지능_개발을_위한_경구약제_이미지_데이터/01.데이터/1.Training/라벨링데이터/단일경구약제_5000종/TL_19_단일.zip
# /home/j-j10b102/166.약품식별_인공지능_개발을_위한_경구약제_이미지_데이터/01.데이터/1.Training/라벨링데이터/단일경구약제_5000종/TL_32_단일.zip
# /home/j-j10b102/166.약품식별_인공지능_개발을_위한_경구약제_이미지_데이터/01.데이터/1.Training/라벨링데이터/단일경구약제_5000종/TL_29_단일.zip
# /home/j-j10b102/166.약품식별_인공지능_개발을_위한_경구약제_이미지_데이터/01.데이터/1.Training/라벨링데이터/단일경구약제_5000종/TL_31_단일.zip
# /home/j-j10b102/166.약품식별_인공지능_개발을_위한_경구약제_이미지_데이터/01.데이터/1.Training/라벨링데이터/단일경구약제_5000종/TL_77_단일.zip
# /home/j-j10b102/166.약품식별_인공지능_개발을_위한_경구약제_이미지_데이터/01.데이터/1.Training/라벨링데이터/단일경구약제_5000종/TL_41_단일.zip
# /home/j-j10b102/166.약품식별_인공지능_개발을_위한_경구약제_이미지_데이터/01.데이터/1.Training/라벨링데이터/단일경구약제_5000종/TL_1_단일.zip
# /home/j-j10b102/166.약품식별_인공지능_개발을_위한_경구약제_이미지_데이터/01.데이터/1.Training/라벨링데이터/단일경구약제_5000종/TL_3_단일.zip
# ...
